# %% [markdown]
# get query molecules from Mpro dataset

# %%
# get lists of filenames in both mpro_all and mpro_fragments dirs
# get filenames that are not in mpro_fragments: all - frag = query_mols

import os
mpro_all = os.listdir('Mpro_all/aligned')
mpro_frag = os.listdir('Mpro_fragments/aligned')

intersection = list(set(mpro_all) & set(mpro_frag))

exception = list(set(mpro_frag) - set(intersection))
print(exception)

query_mols = list(set(mpro_all) ^ set(mpro_frag))
test = list(set(mpro_all) ^ set(intersection))

print(query_mols)
# Out:
# ['.DS_Store']
# ['.DS_Store']
